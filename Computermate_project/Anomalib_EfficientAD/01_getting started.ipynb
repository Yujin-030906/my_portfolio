# %% [markdown]
# # Anomalib 01_getting_started 실행
#
# ### 경로 : examples/notebooks/01_getting_started/getting_started.ipynb

# %% [markdown]
# ### 설치 코드

# %%
# Option - I: Uncomment the next line if you want to install via pip.
# %pip install anomalib
# %anomalib install -v
